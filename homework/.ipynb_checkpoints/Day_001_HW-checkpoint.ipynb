# %% [markdown]
# [作業1] MSE函數
#
# 仿造範例的MAE函數, 自己寫一個MSE函數(參考上面公式)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    mae = 0
    for i in range(len(y)):
        mae = mae + abs(y[i]-yp[i])
    mae = mae/len(y)
    return mae

def mean_squared_error(y, yp):
    mse = 0
    for i in range(len(y)):
        mse = mse + pow((y[i]-yp[i]), 2)
    return mse

# %%
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 20841.798
# The Mean absolute error is 11.613

# %% [markdown]
# [作業2] 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# Real or Not? NLP with Disaster Tweets(https://www.kaggle.com/c/nlp-getting-started/overview)
#
# 1. 你選的這組資料為何重要
#    社群媒體使用者貼文傳達緊急情況，此比例逐漸提高。因此，救災組織和新聞機構亦對監看社群媒體上資訊有一定重視，真實性與否則為考量的重點
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#    Tweeter擷取使用者的貼文
# 3. 蒐集而來的資料型態為何
#    包含貼文地點、文字訊息與照片
# 4. 這組資料想解決的問題如何評估
#    建立模型根據文字訊息斷詞組合，來判斷出事件真實性，依據過去資料train model，若是超過一定threshold則為真

# %% [markdown]
# [作業3]想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#     創造品牌價值(安全快速)、增加客源增加獲利、尋找最佳路徑(考量最短路徑與交通壅塞程度)
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#     車輛定位(地點、里程)，付款機制(時間、費用)，若是搭配app可以了解乘客的身分與年紀 → 了解客群分布，擬定策略
#     各區歷史交通統計數據、交通廣播語音即時更新 → 即時交通壅塞程度
#
# 3. 蒐集而來的資料型態為何
#     車輛定位(地點text、里程float)，付款機制(時間time、費用int)，若是搭配app可以了解乘客的身分text與年紀int
#     各區歷史交通統計數據、交通廣播語音即時更新  → 即時交通壅塞程度(量化int)
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
#     根據廣播語音轉換成文字，再依NLP斷詞中的詞彙，量化來建立模型
